# %% [markdown]
# # Exploring Ebay Car Sales Data

# %% [markdown]
# Esse é um projeto guiado, parte do curso [Data Analyst em Python](https://app.dataquest.io/path/data-analyst), do Dataquest.io
#
# O dataset foi originalmente criado no Kaggle por [orgesleka](https://www.kaggle.com/orgesleka).
#
# O dataset original não está mais disponível no Kaggle, mas você pode encontrá-lo clicando [aqui](https://data.world/data-society/used-cars-data).

# %% [markdown]
# Para efeitos de estudos foram feitas algumas modificações no Dataset:
#
# * Serão utilizados 50000 amostras desses dados para garantir que o código seja executado rapidamente;
# * O dataset foi ligeiramente bagunçado, para se parecer mais com um conjunto de dados da vida real, pois os dados do Kaggle podem ser um pouco mais fáceis de trabalhar.

# %% [markdown]
# ### Dicionário dos dados:
#
# Representação de cada variável no conjunto de dados.

# %% [markdown]
# ```dateCrawled``` -  Quando este anúncio foi rastreado pela primeira vez. (Todos os valores de campo são obtidos a partir desta data.)
# ```name``` - Modelo e marca do carro.
# ```seller``` - Se o vendedor é particular ou revendedor.
# ```offerType``` - O tipo do anúncio.
# ```price``` - O preço de venda do veículo.
# ```abtest``` - Se o anúncio foi incluído ou não no test A/B.
# ```vehicleType``` - O tipo do veículo.
# ```yearOfRegistration``` - O ano de registro do veículo.
# ```gearbox``` - O tipo de transmissão do carro (manual, automático).
# ```powerPS``` - A potência do carro.
# ```model``` - O nome do modelo do carro.
# ```kilometer``` - A quilometragem do veículo.
# ```monthOfRegistration``` - O mês de registro do carro.
# ```fuelType``` - O tipo de combustível.
# ```brand``` - A marca do carro.
# ```notRepairedDamage``` - Se o carro apresenta algum dano que não foi consertado.
# ```dateCreated``` - A data de criação do anúncio.
# ```nrOfPictures``` - O número de fotos no anúncio.
# ```postalCode``` - O código postal da localização do veículo.
# ```lastSeenOnline``` - Quando o anúncio foi visto pela última vez online.

# %% [markdown]
# ### 1/9
# #### Instruções
#
# - [X] Comece escrevendo um parágrafo em uma célula de redução apresentando o projeto e o conjunto de dados.
# - [x] Importar os pandas e bibliotecas NumPy
# - [x] Leia o arquivo autos.csv CSV no pandas e atribua-o ao nome da variável autos.
#      * Tente sem especificar nenhuma codificação (que será UTF-8 por padrão)
#      * Se você receber um erro de codificação, tente as próximas duas codificações mais populares (Latin-1 e Windows-1252) até conseguir ler o arquivo sem erros.
# - [x] Crie uma nova célula apenas com a variável autos e execute esta célula.
#      * Um recurso interessante do notebook jupyter é sua capacidade de renderizar os primeiros e os últimos valores de qualquer objeto pandas.
# - [x] Use os métodos `` `DataFrame.info ()` `` e `` `DataFrame.head ()` `` para imprimir informações sobre o dataframe automático, bem como as primeiras linhas.
#      * Escreva uma célula de marcação descrevendo brevemente suas observações.

# %%
#importar as bibliotecas necessárias a análise e exploração

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# lendo o arquivo de dados autos.csv

autos = pd.read_csv('autos.csv', encoding='Latin-1')

# %%
# inspecionando as informação dos dados

autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
# informacoes sobre o banco e as variaveis disponiveis

autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
# ...

# %%
# inspecionando as primeiras observacoes do bando de dados

autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %%
# dimensao dos dados

autos.shape
# Out:
# (50000, 20)

# %% [markdown]
# ## Observations

# %% [markdown]
# O conjunto de dados possui 20 colunas e 50000 linhas e algumas colunas tem valores nulos.
# Os nomes das colunas estão em ```camelcase``` o que não é o formato recomendados para o Python.
# Por isso iremos converter os nomes das colunas para ```snakecase```, preenchendo os espaços com underscore.

# %% [markdown]
# ### 2/9
# ## Limpar colunas
#
# * [X] Use o atributo DataFrame.columns para imprimir uma matriz dos nomes das colunas existentes.
# * [X] Copie essa matriz e faça as seguintes edições nos nomes das colunas:
#      * yearOfRegistration para registration_year
#      * monthOfRegistration para registration_month
#      * notRepairedDamage a unrepair_damage
#      * dateCreated para ad_created
#      * O resto dos nomes das colunas de camelcase a snakecase.
# * [X] Atribua os nomes das colunas modificadas de volta ao atributo DataFrame.columns.
# * [X] Use DataFrame.head () para ver o estado atual do dataframe automático.
# * [X] Escreva uma célula de redução explicando as mudanças que você fez e por quê.

# %%
# nome de todas as colunas do banco

autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
# modificacoes que serao no vetor de nomes das colunas

new_columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
       'vehicle_type', 'registration_year', 'gearbox', 'power_PS', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
       'last_seen']

# %%
# renomeando colunas

autos.columns = new_columns

# %%
# inspecionando o nome das colunas

autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_PS   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# Agora vamos fazer uma exploração básica dos dados para determinar algumas alterações que podem ser realizadas, por exemplo:
#
# - Colunas do tipo texto, cujos valores sejam os mesmos. Esses valores podem ser descartados já que não contém informações relevantes para a análise.
# - Dados numéricos que estão erroneamente configurados como texto e precisam ser convertidos.

# %% [markdown]
# ### 3/9
# ## Exploração e limpeza inicial dos dados
#
# * [X] Use `` `DataFrame.describe ()` `` para olhar as estatísticas descritivas para todas as colunas.
# * [X] Escreva uma nota de célula de redução:
#      * Quaisquer colunas que tenham principalmente um valor que são candidatas a serem eliminadas
#      * Quaisquer colunas que precisem de mais investigação.
#      * Quaisquer exemplos de dados numéricos armazenados como texto que precisam ser limpos.
# * [X] Se você precisar investigar mais alguma coluna, faça-o e escreva qualquer coisa adicional que encontrar.
# * [X] Você provavelmente descobriu que as colunas de preço e hodômetro são valores numéricos armazenados como texto. Para cada coluna:
#      * Remova quaisquer caracteres não numéricos.
#      * Converta a coluna em um dtipo numérico.
#      * Use DataFrame.rename () para renomear a coluna para odometer_km.

# %%
# analise descritiva basica das variaveis do conjunto

autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-30 19:48:02  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox      power_PS  model  \
# ...

# %%
autos['nr_of_pictures'].unique()
# Out:
# array([0])

# %% [markdown]
# * A coluna nr_of_pictures não contém valores relevantes, todas as linhas são iguais a 0.

# %%
# observacoes nulas nas colunas de dados

autos.isnull().sum()
# Out:
# date_crawled             0
# name                     0
# seller                   0
# offer_type               0
# price                    0
# abtest                   0
# vehicle_type          5095
# registration_year        0
# gearbox               2680
# power_PS                 0
# model                 2758
# odometer                 0
# registration_month       0
# fuel_type             4482
# brand                    0
# unrepaired_damage     9829
# ad_created               0
# nr_of_pictures           0
# postal_code              0
# last_seen                0
# dtype: int64

# %% [markdown]
# * As colunas vehicle_type, gearbox, model, fuel_type e unrepaired_damage contém valores nulos. Pode ser necessário utilizar algum método de limpeza desses dados.

# %%
# inspecao do tipo de cada dado armazenado

autos.dtypes
# Out:
# date_crawled          object
# name                  object
# seller                object
# offer_type            object
# price                 object
# abtest                object
# vehicle_type          object
# registration_year      int64
# gearbox               object
# power_PS               int64
# model                 object
# odometer              object
# registration_month     int64
# fuel_type             object
# brand                 object
# unrepaired_damage     object
# ad_created            object
# nr_of_pictures         int64
# postal_code            int64
# last_seen             object
# dtype: object

# %% [markdown]
# * As colunas price e odometer são do tipo object e deveriam ser do tipo int ou float.

# %%
autos.price.isna().sum()
# Out:
# 0

# %%
# A coluna price não contém valores nulos. 
# Utilizaremos o método str.replace para substituir o símbolo $ 
autos['price'] = autos['price'].str.replace('$', '')
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type  price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  5,000  control          bus               2004
# 1  privat    Angebot  8,500  control    limousine               1997
# 2  privat    Angebot  8,990     test    limousine               2009
# 3  privat    Angebot  4,350  control   kleinwagen               2007
# 4  privat    Angebot  1,350     test        kombi               2003
#
#      gearbox  power_PS   model   odometer  registration_month fuel_type  \
# ...

# %%
# E aqui, aplicando novamente o método str.replace para substituir a vírgula
autos['price'] = autos['price'].str.replace(',', '')
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  5000  control          bus               2004
# 1  privat    Angebot  8500  control    limousine               1997
# 2  privat    Angebot  8990     test    limousine               2009
# 3  privat    Angebot  4350  control   kleinwagen               2007
# 4  privat    Angebot  1350     test        kombi               2003
#
#      gearbox  power_PS   model   odometer  registration_month fuel_type  \
# ...

# %%
# Utilizaremos o método as type para converter price de object para int
autos['price'] = autos['price'].astype(int)

# %%
autos.dtypes
# Out:
# date_crawled          object
# name                  object
# seller                object
# offer_type            object
# price                  int64
# abtest                object
# vehicle_type          object
# registration_year      int64
# gearbox               object
# power_PS               int64
# model                 object
# odometer              object
# registration_month     int64
# fuel_type             object
# brand                 object
# unrepaired_damage     object
# ad_created            object
# nr_of_pictures         int64
# postal_code            int64
# last_seen             object
# dtype: object

# %%
# E agora aplicaremos o mesmo processo a odometer, 
# porém utilizaremos o método replace para substituir a vírgula e a str "km"
# ao mesmo tempo:
autos["odometer"] = (autos["odometer"]
                             .str.replace("km","")
                             .str.replace(",","")
                             .astype(int)
                             )

# %%
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
# Por último iremos renomear a coluna odometer para odometer_km
# utilizando o método rename:
autos.rename({"odometer": "odometer_km"}, axis=1, inplace=True)
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %% [markdown]
# ### 4/9
# ## Explorando odômetro e preço
#
# Na última tela, aprendemos que há várias colunas de texto em que quase todos os valores são iguais (vendedor e tipo_de_ oferta).
#
# Também convertemos as colunas de preço e odômetro em tipos numéricos e renomeamos odômetro para odômetro_km.
#
# Vamos continuar explorando os dados, especificamente procurando dados que não parecem corretos. Começaremos analisando as colunas odometer_km e price. Estas são as etapas que seguiremos:
#
# * Analise as colunas usando valores mínimo e máximo e procure por quaisquer valores que pareçam irrealisticamente altos ou baixos (outliers) que possamos remover.
# * Usaremos:
#     * Series.unique (). Shape para ver quantos valores exclusivos
#     * Series.describe () para visualizar mín. / Máx. / Mediana / média etc.
#     * Series.value_counts (), com algumas variações:
#         * encadeado a .head () se houver muitos valores.
#         * Como Series.value_counts () retorna uma série, podemos usar Series.sort_index () com ascending = True ou False para visualizar os valores mais altos e mais baixos com suas contagens (também pode encadear em head () aqui).
#     * Ao remover outliers, podemos fazer df [(df ["col"]> x) & (df ["col"] <y)], mas é mais legível usar df [df ["col"]. Between ( x, y)]
#
# ______________________________________________________________________________________________
#
# * Para cada uma das colunas odometer_km e preço:
#      * Use as técnicas acima para explorar os dados
#      * Se você descobrir que há outliers, remova-os e escreva um parágrafo de redução explicando sua decisão.
#      * Depois de remover os outliers, faça algumas observações sobre os valores restantes.

# %%
autos['odometer_km'].unique().shape
# Out:
# (13,)

# %%
autos['price'].unique().shape
# Out:
# (2357,)

# %%
# descritivas basicas

autos['odometer_km'].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
# descritivas basicas

autos['price'].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
# contando

autos['odometer_km'].value_counts().head()
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# Name: odometer_km, dtype: int64

# %%
# contando

autos['price'].value_counts().head()
# Out:
# 0       1421
# 500      781
# 1500     734
# 2500     643
# 1000     639
# Name: price, dtype: int64

# %%
autos['odometer_km'].value_counts().sort_index(ascending=False).head()
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# Name: odometer_km, dtype: int64

# %%
autos['price'].value_counts().sort_index(ascending=False).head()
# Out:
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# Name: price, dtype: int64

# %%
autos = autos[autos['price'].between(1,351000)]
autos['price'].describe()
# Out:
# count     48565.000000
# mean       5888.935591
# std        9059.854754
# min           1.000000
# 25%        1200.000000
# 50%        3000.000000
# 75%        7490.000000
# max      350000.000000
# Name: price, dtype: float64

# %% [markdown]
# ### 5/9
# ## Explorando as colunas de data
#
# * [X] Use o fluxo de trabalho que acabamos de descrever para calcular a distribuição de valores nas colunas `` `date_crawled```,` `` ad_created``` e `` `last_seen``` (todas as colunas de string) como porcentagens .
#      * Para incluir valores ausentes na distribuição e usar porcentagens em vez de contagens, encadeie o método `` `Series.value_counts (normalize = True, dropna = False)` ``.
#      * Para classificar por data em ordem crescente (do mais antigo para o mais recente), acorrente o método `` `Series.sort_index ()` ``.
#      * Escreva uma célula de marcação após cada exploração da coluna para explicar suas observações.
# * [X] Use `` `Series.describe ()` `` para entender a distribuição de `` `registration_year```.
#      * Escreva uma célula de marcação explicando suas observações.

# %%
# inspecionando as colunas citadas e seus primeiros elementos

autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
(autos['date_crawled']
        .str[:10]
        .value_counts(normalize=True, dropna=False)
        .sort_index()
        )
# Out:
# 2016-03-05    0.025327
# 2016-03-06    0.014043
# 2016-03-07    0.036014
# 2016-03-08    0.033296
# 2016-03-09    0.033090
# 2016-03-10    0.032184
# 2016-03-11    0.032575
# 2016-03-12    0.036920
# 2016-03-13    0.015670
# 2016-03-14    0.036549
# 2016-03-15    0.034284
# 2016-03-16    0.029610
# 2016-03-17    0.031628
# 2016-03-18    0.012911
# 2016-03-19    0.034778
# 2016-03-20    0.037887
# 2016-03-21    0.037373
# 2016-03-22    0.032987
# 2016-03-23    0.032225
# 2016-03-24    0.029342
# 2016-03-25    0.031607
# 2016-03-26    0.032204
# 2016-03-27    0.031092
# 2016-03-28    0.034860
# 2016-03-29    0.034099
# 2016-03-30    0.033687
# 2016-03-31    0.031834
# 2016-04-01    0.033687
# 2016-04-02    0.035478
# 2016-04-03    0.038608
# 2016-04-04    0.036487
# 2016-04-05    0.013096
# 2016-04-06    0.003171
# 2016-04-07    0.001400
# Name: date_crawled, dtype: float64

# %%
(autos['date_crawled']
        .str[:10]
        .value_counts(normalize=True, dropna=False)
        .sort_values()
        )
# Out:
# 2016-04-07    0.001400
# 2016-04-06    0.003171
# 2016-03-18    0.012911
# 2016-04-05    0.013096
# 2016-03-06    0.014043
# 2016-03-13    0.015670
# 2016-03-05    0.025327
# 2016-03-24    0.029342
# 2016-03-16    0.029610
# 2016-03-27    0.031092
# 2016-03-25    0.031607
# 2016-03-17    0.031628
# 2016-03-31    0.031834
# 2016-03-10    0.032184
# 2016-03-26    0.032204
# 2016-03-23    0.032225
# 2016-03-11    0.032575
# 2016-03-22    0.032987
# 2016-03-09    0.033090
# 2016-03-08    0.033296
# 2016-03-30    0.033687
# 2016-04-01    0.033687
# 2016-03-29    0.034099
# 2016-03-15    0.034284
# 2016-03-19    0.034778
# 2016-03-28    0.034860
# 2016-04-02    0.035478
# 2016-03-07    0.036014
# 2016-04-04    0.036487
# 2016-03-14    0.036549
# 2016-03-12    0.036920
# 2016-03-21    0.037373
# 2016-03-20    0.037887
# 2016-04-03    0.038608
# Name: date_crawled, dtype: float64

# %% [markdown]
# Analisando a distribuição de ```data_crawled``` observa-se que o site foi rastreado pelo menos 1 vez ao dia durante o período de 5 de março a 7 de abril. A distribuição das listagens rastreadas em cada dia é aproximadamente uniforme.

# %%
(autos['last_seen']
        .str[:11]
        .value_counts(normalize=True, dropna=False)
        .sort_index()
        )
# Out:
# 2016-03-05     0.001071
# 2016-03-06     0.004324
# 2016-03-07     0.005395
# 2016-03-08     0.007413
# 2016-03-09     0.009595
# 2016-03-10     0.010666
# 2016-03-11     0.012375
# 2016-03-12     0.023783
# 2016-03-13     0.008895
# 2016-03-14     0.012602
# 2016-03-15     0.015876
# 2016-03-16     0.016452
# 2016-03-17     0.028086
# 2016-03-18     0.007351
# 2016-03-19     0.015834
# 2016-03-20     0.020653
# 2016-03-21     0.020632
# 2016-03-22     0.021373
# 2016-03-23     0.018532
# 2016-03-24     0.019767
# 2016-03-25     0.019211
# 2016-03-26     0.016802
# 2016-03-27     0.015649
# 2016-03-28     0.020859
# 2016-03-29     0.022341
# 2016-03-30     0.024771
# 2016-03-31     0.023783
# 2016-04-01     0.022794
# 2016-04-02     0.024915
# 2016-04-03     0.025203
# 2016-04-04     0.024483
# 2016-04-05     0.124761
# 2016-04-06     0.221806
# 2016-04-07     0.131947
# Name: last_seen, dtype: float64

# %% [markdown]
# O rastreador registrou a data em que viu qualquer anúncio pela última vez, o que nos permite determinar em que dia uma listagem foi removida, provavelmente porque o carro foi vendido.
#
# Os últimos três dias contêm uma quantidade desproporcional de valores 'vistos pela última vez'. Dado que esses valores são de 6 a 10 vezes os valores dos dias anteriores, é improvável que tenha ocorrido um grande aumento nas vendas, e mais provavelmente esses valores estão relacionados ao término do período de rastreamento e não indicam vendas de carros.

# %%
print(autos['ad_created'].str[:10].unique().shape)
(autos['ad_created']
        .str[:10]
        .value_counts(normalize=True, dropna=False)
        .sort_index()
        )
# Out:
# (76,)
# 2015-06-11    0.000021
# 2015-08-10    0.000021
# 2015-09-09    0.000021
# 2015-11-10    0.000021
# 2015-12-05    0.000021
#                 ...
# 2016-04-03    0.038855
# 2016-04-04    0.036858
# 2016-04-05    0.011819
# 2016-04-06    0.003253
# 2016-04-07    0.001256
# Name: ad_created, Length: 76, dtype: float64

# %% [markdown]
# Existe uma grande variedade de datas de criação de anúncios. A maioria cai dentro de 1 a 2 meses da data de listagem, mas alguns são bastante antigos, com o mais antigo em torno de 9 meses.

# %%
autos['registration_year'].describe()
# Out:
# count    48565.000000
# mean      2004.755421
# std         88.643887
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# O ano em que o carro foi registrado pela primeira vez provavelmente indicará a idade do carro. Olhando para esta coluna, notamos alguns valores estranhos. O valor mínimo é 1000, muito antes de os carros serem inventados, e o máximo é 9999, muitos anos no futuro.
#
# Como um carro não pode ser registrado pela primeira vez após a listagem ser vista, qualquer veículo com um ano de registro acima de 2016 é definitivamente impreciso. Determinar o primeiro ano válido é mais difícil. Realisticamente, pode ser em algum lugar nas primeiras décadas do século XX.
#
# Vamos contar o número de listagens com carros que estão fora do intervalo de 1900 a 2016 e ver se é seguro remover essas linhas totalmente ou se precisamos de mais lógica personalizada.

# %% [markdown]
# ### 6/9
# ## Lidando com Dados Incorretos de Ano de Registro
#
#
# * [X] Decida quais os valores mais altos e mais baixos aceitáveis para a coluna `` `registration_year```.
#      * Escreva uma célula de redução explicando sua decisão e por quê.
# * [X] Remova os valores fora dos limites superior e inferior e calcule a distribuição dos valores restantes usando `` `Series.value_counts (normalize = True)` ``.
#      * Escreva uma célula de marcação explicando suas observações.

# %%
(~autos['registration_year'].between(1900,2016)).sum() / autos.shape[0]
# Out:
# 0.038793369710697

# %% [markdown]
# Dado que isso representa menos de 4% de nossos dados, removeremos essas linhas.

# %%
autos = autos[autos['registration_year'].between(1900,2016)]
autos['registration_year'].value_counts(normalize=True).head(10)
# Out:
# 2000    0.067608
# 2005    0.062895
# 1999    0.062060
# 2004    0.057904
# 2003    0.057818
# 2006    0.057197
# 2001    0.056468
# 2002    0.053255
# 1998    0.050620
# 2007    0.048778
# Name: registration_year, dtype: float64

# %% [markdown]
# Utilizando between fizemos uma seleção dos carros registrados entre 1900 e 2016.

# %% [markdown]
# ### 7/9
# ## Explorando Preço por Marca
#
# * [X] Explore os valores únicos na coluna `` `marca``` e decida por quais marcas deseja agregar.
#      * Você pode querer selecionar os 20 primeiros, ou pode querer selecionar aqueles que têm mais de uma certa porcentagem dos valores totais (por exemplo,> 5%).
#      * Lembre-se de que `` `Series.value_counts ()` `` produz uma série com rótulos de índice, então você pode usar o atributo `` `Series.index``` para acessar os rótulos, se desejar.
# * [X] Escreva um pequeno parágrafo descrevendo os dados da marca e explicando quais marcas você escolheu agregar.
# * [X] Crie um dicionário vazio para armazenar seus dados agregados.
#      * Faça um loop sobre suas marcas selecionadas e atribua o preço médio ao dicionário, com o nome da marca como a chave.
#      * Imprima seu dicionário de dados agregados e escreva um parágrafo analisando os resultados.

# %%
autos['brand'].value_counts(normalize=True)
# Out:
# volkswagen        0.211264
# bmw               0.110045
# opel              0.107581
# mercedes_benz     0.096463
# audi              0.086566
# ford              0.069900
# renault           0.047150
# peugeot           0.029841
# fiat              0.025642
# seat              0.018273
# skoda             0.016409
# nissan            0.015274
# mazda             0.015188
# smart             0.014160
# citroen           0.014010
# toyota            0.012703
# hyundai           0.010025
# sonstige_autos    0.009811
# volvo             0.009147
# mini              0.008762
# mitsubishi        0.008226
# honda             0.007840
# kia               0.007069
# alfa_romeo        0.006641
# porsche           0.006127
# suzuki            0.005934
# chevrolet         0.005698
# chrysler          0.003513
# dacia             0.002635
# daihatsu          0.002506
# jeep              0.002271
# subaru            0.002142
# land_rover        0.002099
# saab              0.001649
# ...

# %%
plt.rcParams['figure.dpi'] = 360
sns.set(style="whitegrid")

fig, ax = plt.subplots(figsize=(10,4))
ax = sns.countplot(x = autos['brand'], palette='dark')
ax.set_xticklabels(ax.get_xticklabels(), rotation=55) 
plt.ylabel('')
plt.xlabel('')
plt.xticks(size=6)
plt.title('Autos by Brand')
sns.despine(left=True)
plt.show()

plt.savefig('autosbybrand.png')

# %% [markdown]
# Os fabricantes alemães representam quatro das cinco principais marcas, quase 50% das listagens gerais. A Volkswagen é de longe a marca mais popular, com aproximadamente o dobro dos carros à venda das duas marcas seguintes juntas.
#
# Existem muitas marcas que não têm uma porcentagem significativa de listagens, portanto, limitaremos nossa análise às marcas que representam mais de 5% do total de listagens.

# %%
brand_counts = autos['brand'].value_counts(normalize=True)
common_brands = brand_counts[brand_counts > .05].index
print(common_brands)
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %%
brand_mean_prices = {}

for brand in common_brands:
    brand_only = autos[autos['brand'] == brand]
    mean_price = brand_only['price'].mean()
    brand_mean_prices[brand] = int(mean_price)

brand_mean_prices
# Out:
# {'volkswagen': 5402,
#  'bmw': 8332,
#  'opel': 2975,
#  'mercedes_benz': 8628,
#  'audi': 9336,
#  'ford': 3749}

# %% [markdown]
# Das 5 principais marcas, há uma diferença de preço distinta:
#
# * Audi, BMW e Mercedes Benz são mais caros
# * Ford e Opel são menos caros
# * A Volkswagen está no meio - isso pode explicar sua popularidade, pode ser uma opção do melhor de ambos os mundos.

# %% [markdown]
# ### 8/9
# ## Explorando Milhagem
#
# * [X] Use o método de loop da última tela para calcular a quilometragem média e o preço médio para cada uma das principais marcas, armazenando os resultados em um dicionário.
# * [X] Converta ambos os dicionários em objetos de série, usando o construtor de série.
# * [X] Crie um dataframe a partir do primeiro objeto da série usando o construtor do dataframe.
# * [X] Atribua a outra série como uma nova coluna neste dataframe.
# * [X] Imprima o quadro de dados e escreva um parágrafo analisando os dados agregados.

# %%
# media preco

bmp_series = pd.Series(brand_mean_prices)
pd.DataFrame(bmp_series, columns=['mean_price'])
# Out:
#                mean_price
# volkswagen           5402
# bmw                  8332
# opel                 2975
# mercedes_benz        8628
# audi                 9336
# ford                 3749

# %%
brand_mean_mileage = {}

for brand in common_brands:
    brand_only = autos[autos['brand'] == brand]
    mean_mileage = brand_only['odometer_km'].mean()
    brand_mean_mileage[brand] = int(mean_mileage)

mean_mileage = pd.Series(brand_mean_mileage).sort_values(ascending=False)
mean_prices = pd.Series(brand_mean_prices).sort_values(ascending=False)

# %%
# media milhagem

brand_info = pd.DataFrame(mean_mileage,columns=['mean_mileage'])
brand_info
# Out:
#                mean_mileage
# bmw                  132572
# mercedes_benz        130788
# opel                 129310
# audi                 129157
# volkswagen           128707
# ford                 124266

# %%
brand_info['mean_price'] = mean_prices
brand_info
# Out:
#                mean_mileage  mean_price
# bmw                  132572        8332
# mercedes_benz        130788        8628
# opel                 129310        2975
# audi                 129157        9336
# volkswagen           128707        5402
# ford                 124266        3749

# %% [markdown]
# A gama de quilometragem do carro não varia tanto quanto os preços por marca, em vez disso, todos caem dentro de 10% para as principais marcas. Há uma ligeira tendência para os veículos mais caros terem maior quilometragem, enquanto os veículos mais baratos terão menor quilometragem.
